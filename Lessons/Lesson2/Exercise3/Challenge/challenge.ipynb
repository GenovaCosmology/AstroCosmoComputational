# %%
import sys
sys.path.append("../../")

from pyACC.helpers import ComovingDistanceChallenge, Logger

# %%
student_list = {
    "Anna D'Ambrosio" : ["Anna_DAmbrosio", "Anna_DAmbrosio"],
    "Andrea Gatti" : ["AndreaGatti", "AndreaGatti"],
    "Claudio Guida" : ["ClaudioGuida", "ClaudioGuida"],
    "Moreno Monticelli" : ["Moreno", "Moreno"],
    "Ilaria Risso" : ["ilariarisso", "Ilaria"],
    "Giulia Campailla" : ["giuliac", "giuliac"],
    "Edoardo Maragliano" : ["MaraglianoEdo", "MaraglianoEdo"],
    "Edoardo Martinelli" : ["MartinelliEdoardo", "Martinelli_Edoardo"],
    "Elisa Lentini" : ["Elisa_Lentini", "Elisa"],
    "Gabriele Russo" : ["Gabriele_Russo", "Gabriele_Russo"],
    "Maria Luisa Gallavotti" : ["marialuisa", "MariaLuisaGallavotti"],
    "Massimiliano Chella" : ["M4551", "MASSI"],
    "Gaia Delucchi" : ["GaiaD", "GaiaDelucchi"],
}

# %%
cdc = ComovingDistanceChallenge(student_list=student_list)

# %%
cdc.download_data()
# Out:
# 2024-03-17 21:41:19.292775 :: Anna D'Ambrosio :: ERROR :: The file comoving_distances.txt could not be downloaded from https://raw.githubusercontent.com/GenovaCosmology/AstroCosmoComputational/Anna_DAmbrosio/Students/Anna_DAmbrosio/Lesson2/Exercise3/comoving_distances.txt.
#
# 2024-03-17 21:41:19.847593 :: Andrea Gatti :: INFO :: The file comoving_distances.txt has been downloaded from https://raw.githubusercontent.com/GenovaCosmology/AstroCosmoComputational/AndreaGatti/Students/AndreaGatti/Lesson2/Exercise3/comoving_distances.txt.
#
# 2024-03-17 21:41:20.525667 :: Claudio Guida :: INFO :: The file comoving_distances.txt has been downloaded from https://raw.githubusercontent.com/GenovaCosmology/AstroCosmoComputational/ClaudioGuida/Students/ClaudioGuida/Lesson2/Exercise3/comoving_distances.txt.
#
# ...

# %%
cdc.read_files()
# Out:
# 2024-03-17 21:41:27.301773 :: Comoving Distance Challenge :: ERROR :: No file to read for Anna D'Ambrosio :((
# 2024-03-17 21:41:27.307307 :: Comoving Distance Challenge :: ERROR :: No file to read for Moreno Monticelli :((
# 2024-03-17 21:41:27.307359 :: Comoving Distance Challenge :: ERROR :: No file to read for Ilaria Risso :((
# 2024-03-17 21:41:27.307372 :: Comoving Distance Challenge :: ERROR :: No file to read for Giulia Campailla :((
# 2024-03-17 21:41:27.307381 :: Comoving Distance Challenge :: ERROR :: No file to read for Edoardo Maragliano :((
# 2024-03-17 21:41:27.307390 :: Comoving Distance Challenge :: ERROR :: No file to read for Edoardo Martinelli :((
# 2024-03-17 21:41:27.307399 :: Comoving Distance Challenge :: ERROR :: No file to read for Elisa Lentini :((
# 2024-03-17 21:41:27.312372 :: Comoving Distance Challenge :: ERROR :: No file to read for Massimiliano Chella :((
# ...

# %%
ax = cdc.plot()

# %%
ax = cdc.plot_residuals()

# %%
cdc.print_residuals()
# Out:
# 2024-03-17 21:41:36.920853 :: Comoving Distance Challenge :: INFO :: Residuals for student Andrea Gatti:
# LCDM: 0.13 percent - wCDM: 0.12 percent
# 2024-03-17 21:41:36.921073 :: Comoving Distance Challenge :: INFO :: Residuals for student Claudio Guida:
# LCDM: 9.08 percent - wCDM: 13.24 percent
# 2024-03-17 21:41:36.921161 :: Comoving Distance Challenge :: INFO :: Residuals for student Gabriele Russo:
# LCDM: 0.07 percent - wCDM: 0.07 percent
# 2024-03-17 21:41:36.921210 :: Comoving Distance Challenge :: INFO :: Residuals for student Maria Luisa Gallavotti:
# LCDM: 0.07 percent - wCDM: 0.07 percent
