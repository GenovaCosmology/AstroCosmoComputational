# %%
import sys
sys.path.append("/mnt/c/Users/dambr/Desktop/AstroCosmoComputational/Students/Anna_DAmbrosio/")

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",})

# Import your integration methods
from pyACC.Calculus import *

# Import integration class
from pyACC.cosmology import *

from pyACC.clustering import *

import scipy as sp
from scipy import interpolate
from scipy.misc import derivative

from random import randint

#import corner
import pygtc
import getdist

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'..')))

# %%
# generate two random sets of data to test the counting pairs method

ndim = 3
N_1 = 1000
N_2 = 2000
L = 20
n_bin = 100
random1 = np.random.rand(N_1, ndim)*L
random2 = np.random.rand(N_2, ndim)*L

# %%
#r, DD_random = counting_pairs(random1, random2, L, n_bin=n_bin, output='DD')

# %%
type = 'LS'
r, xi = correlation_function(random1, random2, L, n_bin=n_bin, type=type)

# %%
plt.plot(r, xi, label='Correlation function with '+ str(type))
plt.xlabel(r'$r$')
plt.ylabel(r'$\xi(r)$')
plt.legend()
