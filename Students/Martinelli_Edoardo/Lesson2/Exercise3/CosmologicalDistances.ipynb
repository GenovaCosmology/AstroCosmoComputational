# %%
import sys
sys.path.append("/home/edo/Software/TESI/AstroCosmoComputational/Students/Martinelli_Edoardo/")

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",})

# Import pyACC logger
from pyACC.helpers import Logger

# Set the logger
print = Logger("pyACC.CosmologicalDistances")

# Import integration class
from pyACC.cosmology import *

# Import integration class
from pyACC.Calculus import integrate_f

# Import pandas
import pandas as pd

# %% [markdown]
# # Compute cosmological distances
#
# In this exercise you will keep practicing integration in a cosmological context.
# In particular you will compute cosmological distances.
#
# The basis to compute distances is the Hubble function $H(z)$, which describes the evolution of the backgroud.
#
# for flat $\Lambda$ CDM cosmology it reads:
#
# $$ D_c(z) = \int_0^z \frac{\mathrm{d} z' c}{H(z')} $$
#
# Implement this function, or try your favourite cosmological model!

# %%
# Implement your favourite Hubble function
'''
    # I've implemented in in the distances.py file
def hubble_function(z, ...):
    
    return ...
'''
# Out:
# "\n    # I've implemented in in the distances.py file\ndef hubble_function(z, ...):\n    \n    return ...\n"

# %%
# Now use the function you've implemented to compute cosmological distances
# Use the class you've implemented
# get_distances = ...

# I've used some functions not a class

# %%
# Comoving distance at z=1
print(comoving_distance(1), "Mpc")
# Out:
# ---
# -->  2024-03-06 12:54:34.647675
# ---
# I'm integrating over a function, I used the quad method from scipy.
# 2024-03-06 12:54:34.647985 :: pyACC.CosmologicalDistances  :: 3411.532720249468 Mpc

# %%
# array of redshifts
z_list = np.linspace(0.0001, 2.5, 100)

# Calculate the comoving distance at each redshift in z_list
comoving_dist = comoving_distance(z_list)

# Calculate the angular diameter distance at each redshift in z_list
angular_diameter_dist = angular_diameter_distance(z_list)

# Calculate the luminosity distance at each redshift in z_list
luminosity_dist = luminosity_distance(z_list)

# Calculate the distance modulus at each redshift in z_list
distance_mod = distance_modulus(z_list)
# Out:
# ---
# -->  2024-03-06 12:54:34.675395
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.675579
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.675652
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.675737
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.675804
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.675866
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.675926
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.675987
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.676058
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.676122
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.676199
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.676315
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.676423
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.676526
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.676628
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.676745
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.676859
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.676969
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.677074
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.677181
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.677280
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.677392
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.677489
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.677588
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.677695
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.677797
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.677893
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.677996
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.678103
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.678207
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.678307
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.678408
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.678512
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.678616
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.678715
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.678810
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.678906
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.679003
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.679188
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.679286
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.679401
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.679496
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.679592
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.679684
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.679800
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.679890
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.680000
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.680105
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.680233
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.680320
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.680399
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.680481
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.681414
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.681550
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.681675
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.681761
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.681825
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.681888
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682009
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682077
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682142
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682207
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682267
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682324
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682382
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682468
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682529
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682587
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682643
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682699
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682755
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682811
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682867
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682924
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.682981
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683037
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683094
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683150
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683205
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683262
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683320
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683378
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683434
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683503
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683570
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683623
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683677
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683761
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683852
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683928
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.683993
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684062
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684119
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684191
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684248
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684299
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684352
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684404
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684463
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684515
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684709
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684769
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684822
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684875
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684928
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.684981
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685036
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685111
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685167
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685241
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685397
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685476
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685540
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685604
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685669
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685732
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685835
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685904
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.685966
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686029
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686090
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686151
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686212
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686284
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686353
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686419
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686539
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686618
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686703
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686765
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686827
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686888
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.686947
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687006
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687065
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687124
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687183
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687241
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687300
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687359
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687418
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687483
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687542
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687601
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687659
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687717
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687784
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687844
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687903
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.687972
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688032
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688091
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688150
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688209
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688267
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688328
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688387
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688444
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688503
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688561
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688639
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.688881
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.689060
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.689361
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.689440
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.689514
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.689575
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.689644
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.689706
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.689892
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.690017
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.690144
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.690256
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.690358
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.690492
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.690588
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.690700
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.690831
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.690908
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.690969
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691026
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691081
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691140
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691194
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691249
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691304
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691377
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691464
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691527
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691638
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691734
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691798
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.691860
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.692018
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.692115
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.692173
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.692231
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.692286
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.692376
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.692460
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.693491
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.693588
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.693647
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.693702
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.693757
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.693814
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.693888
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.693967
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694023
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694077
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694149
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694237
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694327
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694397
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694454
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694514
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694615
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694724
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694836
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.694939
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.695044
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.695199
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.695308
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.695416
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.695512
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.695637
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.695735
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.695825
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.695929
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.696032
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.696126
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.696219
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.696317
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.696425
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.696517
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.696614
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.696720
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.696821
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.696924
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.697022
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.697112
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.697216
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.697321
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.697419
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.697523
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.697622
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.697729
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.697827
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.697917
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698011
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698106
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698200
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698288
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698372
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698460
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698563
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698663
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698756
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698846
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.698934
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699027
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699130
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699231
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699321
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699404
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699485
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699571
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699665
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699778
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699873
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.699970
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.700064
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.700163
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.700264
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.700389
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.700488
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.700591
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.700692
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.700792
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.700901
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.701008
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.701156
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.701260
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.701362
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.701466
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.701564
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.701661
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.701755
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.701850
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702021
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702204
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702269
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702330
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702390
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702450
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702510
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702571
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702630
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702691
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702752
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.702999
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.703076
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.703274
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.703371
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.703450
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.703550
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.703650
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.703741
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.703819
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.703895
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.703971
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704048
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704124
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704201
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704277
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704352
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704428
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704504
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704567
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704627
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704687
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704748
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704809
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704868
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704927
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.704996
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705057
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705117
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705176
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705237
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705307
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705371
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705465
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705566
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705694
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705797
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.705902
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.706325
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.706439
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.706534
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.706630
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.706726
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.706856
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.706960
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707072
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707142
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707215
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707469
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707544
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707608
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707668
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707729
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707791
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707853
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707915
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.707977
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708038
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708101
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708161
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708218
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708279
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708339
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708402
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708455
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708508
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708561
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708635
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708691
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708744
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708795
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708846
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708897
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708947
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.708998
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709048
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709099
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709150
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709201
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709255
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709307
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709359
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709410
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709461
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709512
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709562
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709627
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709687
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709739
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709792
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709845
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709901
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.709955
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.710009
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.710064
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.710123
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.710178
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.710231
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.710286
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.710341
# ---
# I'm integrating over a function, I used the quad method from scipy.
# ---
# -->  2024-03-06 12:54:34.710394
# ---
# I'm integrating over a function, I used the quad method from scipy.

# %%
plt.plot(z_list, comoving_dist, lw=3, color="k", label="Comoving distance")

plt.legend()
plt.xlabel("Redshift")
plt.ylabel("Distance [Mpc]");

# %%
plt.plot(z_list, distance_mod, lw=3, color="k", label="Distance modulus")
plt.legend()
plt.xlabel("Redshift")
plt.ylabel("$\mu$ [mag]");

# %% [markdown]
# ## Compare against experimental data
#
#
# Let's plot the SNIa distance moduli from Pantheon+ analysis against your favourite cosmological model.
#
# Check out the [paper](https://arxiv.org/abs/2112.03863).
# Data are stored [here](https://github.com/PantheonPlusSH0ES/PantheonPlusSH0ES.github.io).
# Try to understand which table you should use for the plot.

# %%
# Read the data from Pantheon+ set. 
# Suggestion #1: pandas
# Suggestion #2: read the documentation to understand which column you should pick

# %%
'''
plt.plot(z_list, distance_mod, lw=2, color="k", label="LCDM - Distance modulus", zorder=1000)
plt.errorbar(..., ..., ..., fmt="o", color="0.5", alpha=0.5, label="Pantheon+")

plt.grid(True, color="0.9", ls="--")
plt.legend(loc="lower right")
plt.xlabel("Redshift")
plt.ylabel("$\mu$ [mag]")
'''
# Out:
# '\nplt.plot(z_list, distance_mod, lw=2, color="k", label="LCDM - Distance modulus", zorder=1000)\nplt.errorbar(..., ..., ..., fmt="o", color="0.5", alpha=0.5, label="Pantheon+")\n\nplt.grid(True, color="0.9", ls="--")\nplt.legend(loc="lower right")\nplt.xlabel("Redshift")\nplt.ylabel("$\\mu$ [mag]")\n'
