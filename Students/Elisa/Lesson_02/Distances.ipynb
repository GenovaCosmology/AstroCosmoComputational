# %%
import scipy
import scipy.integrate as integrate
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append("../")
#from pyACC.Calculus import *
from pyACC.cosmology import *

# %%
z_f = 1000
#redshift = np.linspace(0,z_f,1000)
redshift = np.logspace(-2,2,1000)

# %%
plt.loglog(redshift,[Dc(z) for z in redshift])
plt.xlabel('log(z)')
plt.ylabel('log(Dc)')
plt.title('Comoving distance')
# Out:
# Text(0.5, 1.0, 'Comoving distance')

# %%
plt.loglog(redshift,[Da(z) for z in redshift])
plt.xlabel('log(z)')
plt.ylabel('log(Da)')
plt.title('Angular diameter distance')
# Out:
# Text(0.5, 1.0, 'Angular diameter distance')

# %%
plt.loglog(redshift,[Dl(z) for z in redshift])
plt.xlabel('log(z)')
plt.ylabel('log(Dl)')
plt.title('Luminosity distance')
# Out:
# Text(0.5, 1.0, 'Luminosity distance')

# %%
plt.loglog(redshift,[Dm(z) for z in redshift])
plt.xlabel('log(z)')
plt.ylabel('log(Dm)')
plt.title('Distance modulus')
# Out:
# Text(0.5, 1.0, 'Distance modulus')
